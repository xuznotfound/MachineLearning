# %%
# 使用 IPython 的 display 功能
from IPython.display import Image as IPImage, display

# 方法1：直接显示
display(IPImage(filename='./samples_epoch_200.png'))

# 方法2：使用 markdown 方式
from IPython.display import display, Markdown
display(Markdown('![生成的动漫头像](./samples_epoch_200.png)'))

# 方法3：如果已经有 PIL Image 对象
from PIL import Image
pil_img = Image.open('./samples_epoch_200.png')
display(pil_img)  # Jupyter 会自动渲染
